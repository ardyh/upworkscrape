# %%
import pandas as pd

# %%
uk1 = pd.read_csv("../data/result/freelancer_urls_united-kingdom.csv")
uk2 = pd.read_csv("../data/result/freelancer_urls_united-kingdom2.csv")

# %%
uk1.head()
# Out:
#    page                                               link          name
# 0     1  https://www.upwork.com/o/profiles/users/_~0133...       Jill S.
# 1     1  https://www.upwork.com/o/profiles/users/_~0103...  Agnieszka F.
# 2     1  https://www.upwork.com/o/profiles/users/_~0106...      Zofia R.
# 3     1  https://www.upwork.com/o/profiles/users/_~01e8...      Gabie L.
# 4     1  https://www.upwork.com/o/profiles/users/_~01fe...       Arin D.

# %%
uk2.head()
# Out:
#    page                                               link             name
# 0   301  https://www.upwork.com/o/profiles/users/_~0166...         Alfie W.
# 1   301  https://www.upwork.com/o/profiles/users/_~016e...       Lindsay C.
# 2   301  https://www.upwork.com/o/profiles/users/_~017b...  Maria Isabel S.
# 3   301  https://www.upwork.com/o/profiles/users/_~0116...        Sahail A.
# 4   301  https://www.upwork.com/o/profiles/users/_~01dc...        Lauren H.

# %%
print(
'Shape 1', uk1.shape, '\n',
'Shape 2', uk2.shape
)
# Out:
# Shape 1 (3000, 3)
#  Shape 2 (607, 3)

# %%
uk_all = uk1.append(uk2)
uk_all.shape
# Out:
# (3607, 3)

# %%
uk_all = uk_all.reset_index()
# Out:
#       index  page                                               link  \
# 0         0     1  https://www.upwork.com/o/profiles/users/_~0133...
# 1         1     1  https://www.upwork.com/o/profiles/users/_~0103...
# 2         2     1  https://www.upwork.com/o/profiles/users/_~0106...
# 3         3     1  https://www.upwork.com/o/profiles/users/_~01e8...
# 4         4     1  https://www.upwork.com/o/profiles/users/_~01fe...
# 5         5     1  https://www.upwork.com/o/profiles/users/_~01bd...
# 6         6     1  https://www.upwork.com/o/profiles/users/_~016e...
# 7         7     1  https://www.upwork.com/o/profiles/users/_~012f...
# 8         8     1  https://www.upwork.com/o/profiles/users/_~0112...
# 9         9     1  https://www.upwork.com/o/profiles/users/_~0183...
# 10       10     2  https://www.upwork.com/o/profiles/users/_~0143...
# 11       11     2  https://www.upwork.com/o/profiles/users/_~01ca...
# 12       12     2  https://www.upwork.com/o/profiles/users/_~016f...
# ...

# %%
uk_all.drop('index', axis=1, inplace=True)
uk_all.head()
# Out:
#    page                                               link          name
# 0     1  https://www.upwork.com/o/profiles/users/_~0133...       Jill S.
# 1     1  https://www.upwork.com/o/profiles/users/_~0103...  Agnieszka F.
# 2     1  https://www.upwork.com/o/profiles/users/_~0106...      Zofia R.
# 3     1  https://www.upwork.com/o/profiles/users/_~01e8...      Gabie L.
# 4     1  https://www.upwork.com/o/profiles/users/_~01fe...       Arin D.

# %%
uk_all.to_csv("../data/result/freelancer_urls_united-kingdom_all.csv", index=False)
